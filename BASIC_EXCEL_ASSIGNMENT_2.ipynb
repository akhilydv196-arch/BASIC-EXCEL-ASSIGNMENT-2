# %% [markdown]
# **1.Explain the difference between relative, absolute and mixxed reference.**
#  - Relative reference may be said to be as the cell reference that changes with respect to changing cells.
#   - Absolute cell reference may be said to be as the cell reference that remain fixed that generally helps in doing any opperation with respect to that very fixed cell.
#   and we can fix the cell either using dollar sign aur using f4 key
#   - Mixxed cell reference may be said to be as the cell reference that uses both the relative as well as absolute cell reference to purforn amy opperations
#
# **2.  What is formula to calculate total sales of car and bycycles only.**
# - bold text The formula to calculate total sales of car and bycycles are-
#   =sum(carprice,bycycleprice)
# ![SUM.png](data:image/png;base64,...)
#
# **3. Using data write a formula to calculate average sales of item priced above 100 and below 300.**
# - The formula for this is given below-
# ![AVERAGE.png](data:image/png;base64,...)
#
# **4.Using data set count how many customer name are recorded**.
# - The answer is 50
# ![COUNTA.png](data:image/png;base64,...)
# **5.Calculate the total sales of each row using formula.**
# -The total sales of each row are done as shown below-
# ![TOTAL SALES.png](data:image/png;base64,...)
# **6.Total sales of notebooks in north region**
# -The total sales of notebooks in north region are-
# 16293
# ![total sales in north of notebooks.png](data:image/png;base64,...)
# **7.Create a column-chart showing total sales by product**
# -Column-chart are as below
# ![TOTAL SALES BY PRODUCT.png](data:image/png;base64,...)
# **8.Insert a line-chart showing daly sales trend**
# -It is as below-
# ![LINE CHART.png](data:image/png;base64,...)
